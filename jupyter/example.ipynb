# %%
from swan import SensitivityProfile, OptimalCoreAllocation

# %%
exp1 = SensitivityProfile("6ed71a63-14c0-8e3e-3a65-4da9a11eecf6", 500)

# %%
exp1.latency()
# Out:
#         <style  type="text/css" >
#
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d4c96a_34d9_11e7_a8b4_74d435e83d42row0_col7 {
#
# ...

# %%
exp1.latency(normalized=False)
# Out:
#         <style  type="text/css" >
#
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73d939b4_34d9_11e7_a8b4_74d435e83d42row0_col7 {
#
# ...

# %%
exp1.qps()
# Out:
#         <style  type="text/css" >
#
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73dd8546_34d9_11e7_a8b4_74d435e83d42row0_col7 {
#
# ...

# %%
exp1.qps(normalized=False)
# Out:
#         <style  type="text/css" >
#
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73e1bb84_34d9_11e7_a8b4_74d435e83d42row0_col7 {
#
# ...

# %%
exp1.caffe_batches()
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_73e491b0_34d9_11e7_a8b4_74d435e83d42" None>
#
#             <caption>Sensitivity table: caffe image batches of 6ed71a63-14c0-8e3e-3a65-4da9a11eecf6 experiment</caption>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="index_name level0" >
#                   Target QPS
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   50000
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   100000
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   150000
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   200000
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   250000
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   300000
#
#
#
# ...

# %%
exp2 = OptimalCoreAllocation("80ad81ec-e6d7-cfc2-de6c-6c60cb300d7f", 500)

# %%
exp2.latency()
# Out:
#         <style  type="text/css" >
#
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73eb10f8_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
# ...

# %%
exp2.latency(normalized=False)
# Out:
#         <style  type="text/css" >
#
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
#             #T_73f38f76_34d9_11e7_a8b4_74d435e83d42row0_col6 {
#
#                 background-color:  #c0c0c0;
#
#             }
#
# ...

# %%
exp2.qps()
# Out:
#         <style  type="text/css" >
#
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_73fbd7e4_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
# ...

# %%
exp2.qps(normalized=False)
# Out:
#         <style  type="text/css" >
#
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
#             #T_7404424e_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
# ...

# %%
exp2.cpu()
# Out:
#         <style  type="text/css" >
#
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col0 {
#
#                 background:  rgb(114, 140, 0);
#
#                  color:  white;
#
#             }
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col1 {
#
#                 background:  rgb(15, 239, 0);
#
#                  color:  white;
#
#             }
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col2 {
#
#                 background:  rgb(16, 238, 0);
#
#                  color:  white;
#
#             }
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col3 {
#
#                 background:  rgb(23, 231, 0);
#
#                  color:  white;
#
#             }
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col4 {
#
#                 background:  rgb(15, 239, 0);
#
#                  color:  white;
#
#             }
#
#             #T_740c83fa_34d9_11e7_a8b4_74d435e83d42row0_col5 {
#
# ...
