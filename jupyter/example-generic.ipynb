# %%
from generic import optimal_core_allocation

# %%
optimal_core_allocation('35807592-7365-9cf7-dd2f-25ed2892e1a0', slo=250)
# Out:
#         <style  type="text/css" >
#
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col0 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col1 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col2 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col3 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col4 {
#
#                 background: #98cc70;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col5 {
#
#                 background: #ffeda0;
#
#             }
#
#             #T_cbc0561e_29d3_11e7_a0e0_74d435e83d42row0_col6 {
#
#                 background: #a9341f;
#
#                  color:  white;
#
#             }
#
# ...
